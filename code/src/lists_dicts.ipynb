# %%
import pandas as pd

# %%
pd.read_csv("../data/elements_with_bd.csv", sep=";")
# Out:
#      material_id  element_id  quantity  \
# 0             25           1     6.600
# 1             25           2     9.900
# 2             25           3    13.200
# 3             41           4     9.200
# 4             41           5    11.200
# ..           ...         ...       ...
# 237           39         238     1.000
# 238          101         239    23.000
# 239          105         240     0.780
# 240           16         241     0.050
# 241           16         242     0.056
#
#                                       element_name_x  \
# 0                     AAC block - 600 × 200 × 100 mm
# 1                     AAC block - 600 × 200 × 150 mm
# 2                     AAC block - 600 × 200 × 200 mm
# 3                 Concrete block - 390 × 190 × 90 mm
# 4                Concrete block - 390 × 190 × 140 mm
# ..                                               ...
# 237                                     Steel screws
# 238              Ceramic shower tray (70 cm x 90 cm)
# ...
