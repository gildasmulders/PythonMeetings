# %%
import pandas as pd

# %%
df = pd.read_csv("../data/elements_with_bd.csv", sep=";")
list_of_dicts = df.to_dict(orient="records")
list_of_dicts
# Out:
# [{'material_id': 25,
#   'element_id': 1,
#   'quantity': 6.6,
#   'element_name_x': 'AAC block - 600 × 200 × 100 mm',
#   'element_category_x': 'Concrete and Plaster Products',
#   'element_type_x': 'Concrete',
#   'element_functional_unit_x': 'no.',
#   'element_wastage_coefficient_x': 1.0,
#   'element_name_y': 'AAC block - 600 × 200 × 100 mm',
#   'element_category_y': 'Concrete and Plaster Products',
#   'element_type_y': 'Concrete',
#   'element_functional_unit_y': 'no.',
#   'element_wastage_coefficient_y': 1.0,
#   'material_name': 'Autoclaved aerated concrete',
#   'material_category': 'Minerals',
#   'material_type': 'Concrete',
#   'material_functional_unit': 'kg',
# ...
